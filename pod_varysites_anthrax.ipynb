# %% [markdown]
# # Points of Dispense - Anthrax Attack in Downtown Pittsburgh
# #### Minimize total distance and vary number of PODs
# Maxwell Kennady, Nora Murray, Elizabeth Speigle

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %% [markdown]
# ### Optimization

# %% [markdown]
# Read in data from files

# %%
distances = pd.read_csv('data/OD_Pairs_Distances.csv')
population = pd.read_excel('data/BG_master.xlsx')

# %%
dist_miles = distances.pivot(index='block_group', columns='pod_id', values='Miles')
dist_time = distances.pivot(index='block_group', columns='pod_id', values='TravelTime')

# %%
dist = dist_miles.values
N = population['population'].values
prop = population['anthrax'].values

# %% [markdown]
# Create indices for block groups and PODs

# %%
blocks = range(len(N))
pods = range(len(dist[0]))

# %% [markdown]
# Vary number of PODs to open

# %%
pods_open = range(1,48)
pods_open_results = {}

# %%
for i in pods_open: 
    ### Initialize model for POD locations
    m = gp.Model('POD_locations')
    
    ### Add decision variables
    x = m.addVars(pods, vtype=GRB.BINARY, name='x')
    y = m.addVars(blocks, pods, vtype=GRB.BINARY, name='x')
    
    ### Set objective to minimize total distance across the population
    obj = gp.quicksum(dist[j,i] * x[i] * y[j, i] * N[j] * prop[j] 
                  for j in blocks for i in pods)
    m.setObjective(obj, GRB.MINIMIZE)
    
    ### Add constraints
    #  y[i,j] can only be 1 if x[i] is also 1, meaning POD i is opened
    m.addConstrs((y[j, i] <= x[i] for i in pods for j in blocks), name='y_if_x')
    
    # each block group must be assigned one shelter
    m.addConstrs((gp.quicksum(y[j, i] for i in pods) == 1
             for j in blocks), name='all_blocks_assigned')
    
    # number of PODs opened must be less than num_pods
    m.addConstr((gp.quicksum(x[i] for i in pods) <= i), name='pods_opened')
    
    ### Optimize
    print('Solving for:', i, 'PODs')
    m.optimize()
    
    ### Analysis
    block_pod_list = [[j,i] for j in blocks for i in pods if y[j, i].x==1]
    pods_open_results[i] = block_pod_list
# Out:
# Solving for: 1 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xf07c3c46
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 52801 rows and 51747 columns
# Presolve time: 3.88s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 3.92 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 188106
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.881057130576e+05, best bound 1.881057130576e+05, gap 0.0000%
# Solving for: 2 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xad538162
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve time: 0.30s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 346208.48117
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.32 seconds
# Total elapsed time = 6.72s
# Total elapsed time = 11.26s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  280 346208.481    0.00000   100%     -   16s
#      0     0    0.00000    0  254 346208.481    0.00000   100%     -   21s
# H    0     0                    330946.57277    0.00000   100%     -   23s
# H    0     0                    259783.24164    0.00000   100%     -   82s
# H    0     0                    183762.00995    0.00000   100%     -   82s
#      0     0    0.00000    0  200 183762.010    0.00000   100%     -   82s
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -   93s
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -  103s
# *    0     0               0    159955.53855 159955.539  0.00%     -  106s
#
# Explored 1 nodes (148818 simplex iterations) in 106.11 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 159956 183762 183762 ... 346208
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.599555385505e+05, best bound 1.599555385505e+05, gap 0.0000%
# Solving for: 3 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x529e9887
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve time: 0.31s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 346208.48117
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.29 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 346208.481    0.00000   100%     -    2s
#      0     0    0.00000    0  198 346208.481    0.00000   100%     -    5s
# H    0     0                    345760.77384    0.00000   100%     -    6s
# H    0     0                    330946.57277    0.00000   100%     -    8s
#      0     0    0.00000    0  198 330946.573    0.00000   100%     -    9s
# H    0     0                    271860.81835    0.00000   100%     -   37s
# H    0     0                    183762.00995    0.00000   100%     -   37s
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -   37s
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -   44s
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -   45s
# *    0     0               0    153092.30654 153092.307  0.00%     -   53s
#
# Explored 1 nodes (68205 simplex iterations) in 53.33 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 153092 183762 183762 ... 346208
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.530923065371e+05, best bound 1.530923065371e+05, gap 0.0000%
# Solving for: 4 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xa03d9013
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve time: 0.32s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 183762.00995
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.28 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -    2s
#      0     0    0.00000    0  199 183762.010    0.00000   100%     -    4s
# H    0     0                    181209.57101    0.00000   100%     -   22s
#      0     0    0.00000    0  199 181209.571    0.00000   100%     -   23s
# H    0     0                    159955.53855    0.00000   100%     -   44s
#      0     0    0.00000    0  198 159955.539    0.00000   100%     -   44s
#      0     0    0.00000    0  198 159955.539    0.00000   100%     -   49s
# H    0     0                    159938.66214    0.00000   100%     -   70s
#      0     0    0.00000    0  198 159938.662    0.00000   100%     -   70s
#      0     0    0.00000    0  198 159938.662    0.00000   100%     -   71s
# *    0     0               0    151270.29980 151270.300  0.00%     -   81s
#
# Explored 1 nodes (93337 simplex iterations) in 81.33 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 151270 159939 159956 ... 183762
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.512702997988e+05, best bound 1.512702997988e+05, gap 0.0000%
# Solving for: 5 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xcb9f832f
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve time: 0.34s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 183762.00995
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.41 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 183762.010    0.00000   100%     -    2s
#      0     0    0.00000    0  199 183762.010    0.00000   100%     -    5s
#      0     0    0.00000    0  200 183762.010    0.00000   100%     -   17s
#      0     0    0.00000    0  200 183762.010    0.00000   100%     -   21s
# H    0     0                    181209.57101    0.00000   100%     -   47s
#      0     0    0.00000    0  198 181209.571    0.00000   100%     -   48s
# H    0     0                    179544.43879    0.00000   100%     -   78s
# H    0     0                    179318.64088    0.00000   100%     -   78s
# H    0     0                    159955.53855    0.00000   100%     -   78s
#      0     0    0.00000    0  198 159955.539    0.00000   100%     -   78s
#      0     0    0.00000    0  198 159955.539    0.00000   100%     -   80s
# *    0     0               0    151108.84214 151108.842  0.00%     -   89s
#
# Explored 1 nodes (84972 simplex iterations) in 89.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 151109 159956 159956 ... 183762
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.511088421388e+05, best bound 1.511088421388e+05, gap 0.0000%
# Solving for: 6 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x1ef5cc16
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.40s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 181209.57101
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.27 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 181209.571    0.00000   100%     -    2s
#      0     0    0.00000    0  199 181209.571    0.00000   100%     -    5s
#      0     0    0.00000    0  200 181209.571    0.00000   100%     -    9s
# H    0     0                    181091.56859    0.00000   100%     -   12s
#      0     0    0.00000    0  202 181091.569    0.00000   100%     -   12s
# H    0     0                    179544.43879    0.00000   100%     -   34s
# H    0     0                    176556.38571    0.00000   100%     -   34s
# H    0     0                    157407.80147    0.00000   100%     -   34s
#      0     0    0.00000    0  198 157407.801    0.00000   100%     -   35s
# H    0     0                    154448.57497    0.00000   100%     -  102s
# H    0     0                    152930.84888    0.00000   100%     -  102s
#      0     0    0.00000    0  198 152930.849    0.00000   100%     -  102s
#      0     0    0.00000    0  198 152930.849    0.00000   100%     -  103s
# *    0     0               0    150995.29021 150995.290  0.00%     -  120s
#
# Explored 1 nodes (99357 simplex iterations) in 120.81 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 150995 152931 154449 ... 181210
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 7 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x3909ed86
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+00]
# Presolve time: 0.43s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 181096.01908
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.35 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 181096.019    0.00000   100%     -    2s
#      0     0    0.00000    0 2010 181096.019    0.00000   100%     -    8s
# H    0     0                    176281.37612    0.00000   100%     -   50s
# H    0     0                    153092.30654    0.00000   100%     -   50s
#      0     0    0.00000    0  200 153092.307    0.00000   100%     -   50s
#      0     0    0.00000    0  201 153092.307    0.00000   100%     -   52s
#      0     0    0.00000    0  206 153092.307    0.00000   100%     -   65s
#      0     0    0.00000    0  206 153092.307    0.00000   100%     -   69s
# H    0     0                    152930.84888    0.00000   100%     -   71s
# *    0     0               0    150995.29021 150995.290  0.00%     -   76s
#
# Explored 1 nodes (60077 simplex iterations) in 76.37 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 150995 152931 152931 ... 181096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 8 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x277d93b7
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Presolve time: 0.19s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 181096.01908
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.33 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 181096.019    0.00000   100%     -    2s
#      0     0    0.00000    0  925 181096.019    0.00000   100%     -    7s
# H    0     0                    180537.35970    0.00000   100%     -   45s
# H    0     0                    157407.80147    0.00000   100%     -   45s
#      0     0    0.00000    0  200 157407.801    0.00000   100%     -   45s
#      0     0    0.00000    0  202 157407.801    0.00000   100%     -   56s
# H    0     0                    151270.29980    0.00000   100%     -   60s
#      0     0    0.00000    0  208 151270.300    0.00000   100%     -   62s
# *    0     0               0    150995.29021 150995.290  0.00%     -   67s
#
# Explored 1 nodes (54621 simplex iterations) in 67.78 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 150995 151270 157408 ... 181096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 9 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xa2351062
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Presolve time: 0.42s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 578942.29634
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.35 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
#      0     0    0.00000    0  199 380925.556    0.00000   100%     -    5s
#      0     0    0.00000    0  200 380925.556    0.00000   100%     -   11s
# H    0     0                    330426.95625    0.00000   100%     -   11s
#      0     0    0.00000    0  307 330426.956    0.00000   100%     -   12s
# H    0     0                    241508.07221    0.00000   100%     -   13s
# H    0     0                    240237.34034    0.00000   100%     -   16s
#      0     0    0.00000    0  204 240237.340    0.00000   100%     -   16s
#      0     0    0.00000    0  200 240237.340    0.00000   100%     -   20s
#      0     0    0.00000    0  198 240237.340    0.00000   100%     -   22s
# *    0     0               0    150995.29021 150995.290  0.00%     -   29s
#
# Explored 1 nodes (75669 simplex iterations) in 29.94 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 150995 240237 240237 ... 578942
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 10 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x8a5a56eb
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.43s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 701781.80681
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.43 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
# H    0     0                    283669.99764    0.00000   100%     -    2s
# H    0     0                    188105.71306    0.00000   100%     -    2s
# H    0     0                    181096.01908    0.00000   100%     -    7s
#      0     0    0.00000    0 1741 181096.019    0.00000   100%     -    9s
# H    0     0                    181031.04977    0.00000   100%     -   13s
# H    0     0                    180978.01666    0.00000   100%     -   13s
# H    0     0                    157294.24955    0.00000   100%     -   13s
# H    0     0                    153092.30654    0.00000   100%     -   50s
#      0     0    0.00000    0  198 153092.307    0.00000   100%     -   51s
#      0     0    0.00000    0  198 153092.307    0.00000   100%     -   65s
#      0     0    0.00000    0  199 153092.307    0.00000   100%     -   73s
# *    0     0               0    150995.29021 150995.290  0.00%     -   78s
#
# Explored 1 nodes (66105 simplex iterations) in 78.17 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 150995 153092 153092 ... 380926
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 11 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xcd61e550
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.41s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 1173583.8673
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.23 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
# H    0     0                    294765.02014    0.00000   100%     -    2s
#      0     0    0.00000    0  199 294765.020    0.00000   100%     -    5s
# H    0     0                    181209.57101    0.00000   100%     -    9s
# H    0     0                    181144.60170    0.00000   100%     -   11s
#      0     0    0.00000    0  210 181144.602    0.00000   100%     -   11s
# H    0     0                    157407.80147    0.00000   100%     -   12s
#      0     0    0.00000    0  210 157407.801    0.00000   100%     -   13s
# H    0     0                    153092.30654    0.00000   100%     -   31s
# H    0     0                    152930.84888    0.00000   100%     -   31s
# H    0     0                    152817.29695    0.00000   100%     -   31s
#      0     0    0.00000    0  201 152817.297    0.00000   100%     -   31s
#      0     0    0.00000    0 1387 152817.297    0.00000   100%     -   34s
#      0     0    0.00000    0  202 152817.297    0.00000   100%     -   48s
#      0     0    0.00000    0  202 152817.297    0.00000   100%     -   49s
# *    0     0               0    150995.29021 150995.290  0.00%     -   57s
#
# Explored 1 nodes (70356 simplex iterations) in 57.27 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 150995 152817 152817 ... 380926
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 12 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x629b332f
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.19s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 752150.78758
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    1s
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    4s
# H    0     0                    259840.36609    0.00000   100%     -    5s
# H    0     0                    157289.79905    0.00000   100%     -    7s
#      0     0    0.00000    0  198 157289.799    0.00000   100%     -    9s
# H    0     0                    155585.79473    0.00000   100%     -   11s
# H    0     0                    152812.84646    0.00000   100%     -   27s
#      0     0    0.00000    0  202 152812.846    0.00000   100%     -   27s
#      0     0    0.00000    0  198 152812.846    0.00000   100%     -   38s
#      0     0    0.00000    0  198 152812.846    0.00000   100%     -   54s
#      0     0    0.00000    0  198 152812.846    0.00000   100%     -   55s
# *    0     0               0    150995.29021 150995.290  0.00%     -   65s
#
# Explored 1 nodes (89957 simplex iterations) in 65.16 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 150995 152813 152813 ... 752151
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 13 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x76cc2e2b
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.43s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 880284.26088
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.39 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
#      0     0    0.00000    0  199 380925.556    0.00000   100%     -    5s
# H    0     0                    330426.95625    0.00000   100%     -   22s
# H    0     0                    183648.45803    0.00000   100%     -   22s
# H    0     0                    159841.98663    0.00000   100%     -   22s
#      0     0    0.00000    0  200 159841.987    0.00000   100%     -   22s
# H    0     0                    155472.24281    0.00000   100%     -   31s
#      0     0    0.00000    0  198 155472.243    0.00000   100%     -   33s
#      0     0    0.00000    0  198 155472.243    0.00000   100%     -   44s
#      0     0    0.00000    0  198 155472.243    0.00000   100%     -   54s
#      0     0    0.00000    0  198 155472.243    0.00000   100%     -   55s
# *    0     0               0    150995.29021 150995.290  0.00%     -   68s
#
# Explored 1 nodes (94239 simplex iterations) in 68.11 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 150995 155472 155472 ... 880284
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 14 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x18eed5e5
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.49s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 1023771.6615
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.35 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    4s
#      0     0    0.00000    0  204 380925.556    0.00000   100%     -    7s
# H    0     0                    188105.71306    0.00000   100%     -    8s
#      0     0    0.00000    0  200 188105.713    0.00000   100%     -   10s
#      0     0    0.00000    0  201 188105.713    0.00000   100%     -   11s
#      0     0    0.00000    0  204 188105.713    0.00000   100%     -   14s
#      0     0    0.00000    0  201 188105.713    0.00000   100%     -   15s
# *    0     0               0    150995.29021 150995.290  0.00%     -   19s
#
# Explored 1 nodes (66558 simplex iterations) in 19.33 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 150995 188106 188106 ... 1.02377e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 15 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x6e63bf06
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.19s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 648263.34051
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.15 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -
seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    3s
#      0     0    0.00000    0  199 380925.556    0.00000   100%     -    6s
# H    0     0                    181031.04977    0.00000   100%     -   24s
# H    0     0                    157294.24955    0.00000   100%     -   24s
# H    0     0                    155472.24281    0.00000   100%     -   24s
# H    0     0                    152817.29695    0.00000   100%     -   24s
#      0     0    0.00000    0  200 152817.297    0.00000   100%     -   24s
#      0     0    0.00000    0  990 152817.297    0.00000   100%     -   27s
# H    0     0                    152812.84646    0.00000   100%     -   47s
#      0     0    0.00000    0  199 152812.846    0.00000   100%     -   47s
# H    0     0                    151108.84214    0.00000   100%     -   50s
#      0     0    0.00000    0  220 151108.842    0.00000   100%     -   60s
#      0     0    0.00000    0  218 151108.842    0.00000   100%     -   61s
# *    0     0               0    150995.29021 150995.290  0.00%     -   69s
#
# Explored 1 nodes (75072 simplex iterations) in 69.13 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 150995 151109 151109 ... 1.23041e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 19 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0x3addf620
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.43s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 294765.02014
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.32 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 294765.020    0.00000   100%     -    2s
#      0     0    0.00000    0  199 294765.020    0.00000   100%     -    5s
#      0     0    0.00000    0  200 294765.020    0.00000   100%     -   11s
# H    0     0                    181144.60170    0.00000   100%     -   12s
#      0     0    0.00000    0  200 181144.602    0.00000   100%     -   12s
#      0     0    0.00000    0  200 181144.602    0.00000   100%     -   14s
# H    0     0                    164391.26144    0.00000   100%     -   40s
# H    0     0                    157294.24955    0.00000   100%     -   40s
# H    0     0                    151270.29980    0.00000   100%     -   42s
#      0     0    0.00000    0  199 151270.300    0.00000   100%     -   42s
# H    0     0                    151108.84214    0.00000   100%     -   68s
#      0     0    0.00000    0  198 151108.842    0.00000   100%     -   69s
#      0     0    0.00000    0  198 151108.842    0.00000   100%     -   70s
# *    0     0               0    150995.29021 150995.290  0.00%     -   81s
#
# Explored 1 nodes (87821 simplex iterations) in 81.98 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 150995 151109 151109 ... 294765
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 20 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xc092fd4f
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.43s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 888439.41464
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.19 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
#      0     0    0.00000    0  298 380925.556    0.00000   100%     -    5s
# H    0     0                    236908.33377    0.00000   100%     -   16s
#      0     0    0.00000    0  201 236908.334    0.00000   100%     -   16s
# H    0     0                    176281.37612    0.00000   100%     -   18s
# H    0     0                    175658.75966    0.00000   100%     -   36s
#      0     0    0.00000    0  199 175658.760    0.00000   100%     -   37s
# H    0     0                    157284.71647    0.00000   100%     -   53s
# H    0     0                    152978.75461    0.00000   100%     -   53s
# H    0     0                    150995.29021    0.00000   100%     -   53s
#      0     0    0.00000    0  199 150995.290    0.00000   100%     -   53s
#      0     0    0.00000    0  199 150995.290    0.00000   100%     -   55s
#      0     0     cutoff    0      150995.290 150995.290  0.00%     -   61s
#
# Explored 1 nodes (71787 simplex iterations) in 61.87 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 150995 150995 152979 ... 888439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 21 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xe3a5d670
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.36s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 483855.50690
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.30 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    2s
#      0     0    0.00000    0  199 380925.556    0.00000   100%     -    5s
# H    0     0                    193259.07528    0.00000   100%     -    6s
# H    0     0                    181031.04977    0.00000   100%     -   24s
# H    0     0                    178596.63511    0.00000   100%     -   24s
# H    0     0                    152817.29695    0.00000   100%     -   24s
#      0     0    0.00000    0  200 152817.297    0.00000   100%     -   25s
#      0     0    0.00000    0  395 152817.297    0.00000   100%     -   27s
#      0     0    0.00000    0  199 152817.297    0.00000   100%     -   31s
#      0     0    0.00000    0  200 152817.297    0.00000   100%     -   39s
#      0     0    0.00000    0  200 152817.297    0.00000   100%     -   40s
# *    0     0               0    150995.29021 150995.290  0.00%     -   49s
#
# Explored 1 nodes (68449 simplex iterations) in 49.78 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve time: 0.19s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 581006.36297
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    0s
# H    0     0                    330946.57277    0.00000   100%     -    1s
#      0     0    0.00000    0  213 330946.573    0.00000   100%     -    2s
#      0     0    0.00000    0  199 330946.573    0.00000   100%     -    4s
# H    0     0                    152215.75911    0.00000   100%     -   16s
# H    0     0                    150995.29021    0.00000   100%     -   16s
#      0     0    0.00000    0  229 150995.290    0.00000   100%     -   16s
#      0     0    0.00000    0  230 150995.290    0.00000   100%     -   17s
#      0     0    0.00000    0  212 150995.290    0.00000   100%     -   18s
#      0     0    0.00000    0  203 150995.290    0.00000   100%     -   21s
#      0     0    0.00000    0  203 150995.290    0.00000   100%     -   21s
#      0     0     cutoff    0      150995.290 150995.290  0.00%     -   26s
#
# Explored 1 nodes (53202 simplex iterations) in 26.85 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 150995 150995 152216 ... 581006
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 46 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xbf6ea955
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve time: 0.16s
# Presolved: 57407 rows, 56353 columns, 168965 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
# Found heuristic solution: objective 453610.82204
# Found heuristic solution: objective 380925.55602
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 380925.556    0.00000   100%     -    0s
# H    0     0                    330946.57277    0.00000   100%     -    1s
#      0     0    0.00000    0  213 330946.573    0.00000   100%     -    2s
#      0     0    0.00000    0  199 330946.573    0.00000   100%     -    4s
# H    0     0                    152215.75911    0.00000   100%     -   15s
# H    0     0                    150995.29021    0.00000   100%     -   15s
#      0     0    0.00000    0  229 150995.290    0.00000   100%     -   15s
#      0     0    0.00000    0 1200 150995.290    0.00000   100%     -   16s
#      0     0    0.00000    0  200 150995.290    0.00000   100%     -   20s
#      0     0    0.00000    0  201 150995.290    0.00000   100%     -   26s
#      0     0    0.00000    0  201 150995.290    0.00000   100%     -   26s
#      0     0     cutoff    0      150995.290 150995.290  0.00%     -   29s
#
# Explored 1 nodes (79664 simplex iterations) in 29.91 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 150995 150995 152216 ... 453611
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%
# Solving for: 47 PODs
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 52801 rows, 51747 columns and 155147 nonzeros
# Model fingerprint: 0xeffe8771
# Model has 4606 quadratic objective terms
# Variable types: 0 continuous, 51747 integer (51747 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 576318.44272
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.17s
# Presolved: 57406 rows, 56353 columns, 168918 nonzeros
# Variable types: 0 continuous, 56353 integer (56353 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 4299 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  198 576318.443    0.00000   100%     -    0s
# H    0     0                    345760.77384    0.00000   100%     -    1s
#      0     0    0.00000    0 2157 345760.774    0.00000   100%     -    4s
# H    0     0                    330426.95625    0.00000   100%     -   15s
# H    0     0                    150995.29021    0.00000   100%     -   15s
#      0     0    0.00000    0  205 150995.290    0.00000   100%     -   15s
#      0     0    0.00000    0  213 150995.290    0.00000   100%     -   15s
#      0     0    0.00000    0  204 150995.290    0.00000   100%     -   17s
#      0     0    0.00000    0  204 150995.290    0.00000   100%     -   19s
#
# Cutting planes:
#   Clique: 1998
#   MIR: 488
#   RLT: 8
#
# Explored 1 nodes (57549 simplex iterations) in 22.67 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 150995 330427 345761 576318
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.509952902143e+05, best bound 1.509952902143e+05, gap 0.0000%

# %%
pods_anthrax_total = open('pods_anthrax_total','wb') 
pickle.dump(pods_open_results, pods_anthrax_total)                      
pods_anthrax_total.close()
